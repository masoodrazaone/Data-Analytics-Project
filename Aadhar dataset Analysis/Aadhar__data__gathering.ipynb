# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d1=pd.read_csv("/content/api_data_aadhar_enrolment_0_500000.csv")
d2=pd.read_csv("/content/api_data_aadhar_enrolment_1000000_1006029.csv")
d3=pd.read_csv("/content/api_data_aadhar_enrolment_500000_1000000.csv")

# %%
final_enrol_data=pd.concat([d1,d2,d3],ignore_index=True)

# %%
final_enrol_data.to_csv("final_enrol_data",index=False)

# %%
enrol_data=pd.read_csv("/content/final_enrol_data")

# %%
enrol_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1006029 entries, 0 to 1006028
# Data columns (total 7 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   date            1006029 non-null  object
#  1   state           1006029 non-null  object
#  2   district        1006029 non-null  object
#  3   pincode         1006029 non-null  int64
#  4   age_0_5         1006029 non-null  int64
#  5   age_5_17        1006029 non-null  int64
#  6   age_18_greater  1006029 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 53.7+ MB

# %% [markdown]
# Demographic

# %%
df1=pd.read_csv("/content/api_data_aadhar_demographic_0_500000.csv")
df2=pd.read_csv("/content/api_data_aadhar_demographic_500000_1000000.csv")
df3=pd.read_csv("/content/api_data_aadhar_demographic_1000000_1500000.csv")
df4=pd.read_csv("/content/api_data_aadhar_demographic_1500000_2000000.csv")
df5=pd.read_csv("/content/api_data_aadhar_demographic_2000000_2071700.csv")

# %%
final_demographic_df=pd.concat([df1,df2,df3,df4,df5],ignore_index=True)

# %%
final_demographic_df.to_csv("Final_demo_data.csv",index=False)

# %%
demo_data=pd.read_csv("/content/Final_demo_data.csv")

# %%
demo_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2071700 entries, 0 to 2071699
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           object
#  1   state          object
#  2   district       object
#  3   pincode        int64
#  4   demo_age_5_17  int64
#  5   demo_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 94.8+ MB

# %% [markdown]
# Biometric

# %%
d1=pd.read_csv("/content/api_data_aadhar_biometric_0_500000.csv")
d2=pd.read_csv("/content/api_data_aadhar_biometric_1000000_1500000.csv")
d3=pd.read_csv("/content/api_data_aadhar_biometric_1500000_1861108.csv")
d4=pd.read_csv("/content/api_data_aadhar_biometric_500000_1000000.csv")

# %%
final_biometric_data=pd.concat([d1,d2,d3,d4,],ignore_index=True)

# %%
final_biometric_data.to_csv("final_bio_data.csv",index=False)

# %%
bio_data=pd.read_csv("/content/final_bio_data.csv")

# %%
bio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1861108 entries, 0 to 1861107
# Data columns (total 6 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   date          object
#  1   state         object
#  2   district      object
#  3   pincode       int64
#  4   bio_age_5_17  int64
#  5   bio_age_17_   int64
# dtypes: int64(3), object(3)
# memory usage: 85.2+ MB
